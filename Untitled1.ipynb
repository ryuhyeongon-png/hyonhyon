# %% [markdown]
# <a href="https://colab.research.google.com/github/ryuhyeongon-png/hyonhyon/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://news.ycombinator.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.find_all("span", class_="titleline")

with open("news.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["タイトル"])
    for title in titles[:10]:
        writer.writerow([title.text])

print("保存完了！")
# Out:
# 保存完了！

# %%
import pandas as pd
df = pd.read_csv("news.csv")
print(df)
# Out:
#                                                 タイトル
# 0  Microsoft open-sources "the earliest DOS sourc...
# 1  Amazon Web Services – Four Years and Out (adve...
# 2  Why Is Vivado 2026.1 Dropping Linux Support fo...
# 3  Scammers are abusing an internal Microsoft acc...
# 4                            Wake up! 16b (111mb.de)
# 5  Alexander Grothendieck Revolutionized 20th-Cen...
# 6  Time to talk about my writerdeck (veronicaexpl...
# 7  Green card seekers must leave U.S. to apply, T...
# 8                  On The <dl> (2021) (benmyers.dev)
# 9    Buildcraft Is a Compiler Problem (mitander.xyz)

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://news.ycombinator.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.find_all("span", class_="titleline")

with open("news_with_url.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["タイトル", "URL"])
    for title in titles[:10]:
        link = title.find("a")
        writer.writerow([link.text, link["href"]])

print("保存完了！")
# Out:
# 保存完了！

# %%
df = pd.read_csv("news_with_url.csv")
print(df)
# Out:
#                                                 タイトル  \
# 0  Microsoft open-sources "the earliest DOS sourc...
# 1           Amazon Web Services – Four Years and Out
# 2  Why Is Vivado 2026.1 Dropping Linux Support fo...
# 3  Scammers are abusing an internal Microsoft acc...
# 4                                       Wake up! 16b
# 5  Alexander Grothendieck Revolutionized 20th-Cen...
# 6                   Time to talk about my writerdeck
# 7  Green card seekers must leave U.S. to apply, T...
# 8                                 On The <dl> (2021)
# 9                   Buildcraft Is a Compiler Problem
#
#                                                  URL
# 0  https://arstechnica.com/gadgets/2026/04/micros...
# 1    https://www.adventuresinoss.com/aws-four-years/
# 2  https://adaptivesupport.amd.com/s/question/0D5...
# 3  https://techcrunch.com/2026/05/21/scammers-are...
# 4  https://hellmood.111mb.de/wake_up_16b_writeup....
# 5  https://www.quantamagazine.org/how-alexander-g...
# ...
